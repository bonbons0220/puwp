# %% [markdown]
# # setup-param.ipynb
# Set up parameters for pushing Wordpress.

# %% [markdown]
# ## Overview
# This notebook reads and writes an input parameter file to run push-wordpress.ipynb.

# %%
import yaml
import io
import datetime

# %% [markdown]
# ## Functions

# %%
def showmenu(menu):
    """Shows a menu and returns validated option or default"""

    # get option
    print('\n')  
    for k,v in menu.items():
        print( k + ' : ' + v )
    option = (input('Choose an option: [E]\n') or 'E')
    
    # validate it
    if ( option in menu.keys() ) : 
        result = option
    else:
        print( '"' + option + '" is not on the menu. \n')
        result = 'R'

    return result

# %%
def editparam(editable):
    """Shows current parameters"""
    
    print('\nParameters: \n')
    for k,v in sorted(data.items()):
        print( data[k]['label'] + ' : ' + data[k]['value'] )

    if (editable) :
        print('\nEnter a new value or [enter] to keep existing value.\n')
        for k,v in sorted(data.items()):
            data[k]['value'] = ( input( data[k]['label'] + ' : [' + data[k]['value'] + '] ' ) or data[k]['value'] )
        print('\n')

        return data

# %%
def readparam():
    """Read parameters from file."""
    
    # Get filename
    datafile = ( input('Enter parameter filename [defaults.yaml]') or 'defaults.yaml' );
    
    # Read YAML file
    with io.open( datafile , 'r') as stream:
        try:
            data = yaml.load(stream)
        except yaml.YAMLError as exc:
            print(exc)
            
    return data

# %%
def writeparam( data ):
    """Write] parameters from file."""
    
    # Get filename
    datafile = ( input('Enter parameters filename [defaults.yaml]') or 'defaults.yaml' );
    
    # Write YAML file
    with io.open( datafile , 'w', encoding='utf8') as outfile:
        try:
            yaml.dump( data , outfile , default_flow_style=False, allow_unicode=True)
        except yaml.YAMLError as exc:
            print(exc)

# %% [markdown]
# ## Data

# %%
data={
    '1targetdomain' : { 
        'label' : 'Target domain: ',
        'value' : 'www.example.org' } ,
    '2sourcedomain' : { 
        'label' : 'Source domain: ',
        'value'	: 'test.example.org' } ,
    '3targetpath'   : { 
        'label' : 'Target path: ',
        'value'	: '/var/www/example.org/prod' },
    '4sourcepath'   : { 
        'label' : 'Source path: ',
        'value'	: '/var/www/example.org/test' },
    '5deploypath'   : {	
        'label' : 'Deploy path: ',
        'value'	: '/var/www/example.org/deploy' },
    '6targetDB'     : { 
        'label' : 'Target database: ',
        'value'	: 'examplewp_prod ' },
    '7sourceDB'     : { 
        'label' : 'Source database: ',
        'value'	: 'examplewp_test' } 
}

menu = {'R':'[Read input parameters]',
       'E':'[E]dit input parameters',
       'W':'[W]rite input parameters',
       'X':'E[X]it'}

# %% [markdown]
# ## Main

# %%
# main loop
while (True):

    # show parameters
    editparam(False)
    
    # show menu
    option = showmenu(menu)
    
    if (option) == 'R' : 
        data = readparam()

    if (option) == 'W' : 
        writeparam( data )
        
    if (option) == 'E' : 
        data = editparam(True)
        
    if (option) == 'X': break
# Out:
# Parameters:
#
# Target domain:  : www.example.org
# Source domain:  : test.example.org
# Target path:  : /var/www/example.org/prod
# Source path:  : /var/www/example.org/test
# Deploy path:  : /var/www/example.org/deploy
# Target database:  : examplewp_prod
# Source database:  : examplewp_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
# E
#
# Parameters:
#
# Target domain:  : www.example.org
# Source domain:  : test.example.org
# Target path:  : /var/www/example.org/prod
# Source path:  : /var/www/example.org/test
# Deploy path:  : /var/www/example.org/deploy
# Target database:  : examplewp_prod
# Source database:  : examplewp_test
#
# Enter a new value or [enter] to keep existing value.
#
# Target domain:  : [www.example.org] www.sdss.org
# Source domain:  : [test.example.org] test.sdss.org
# Target path:  : [/var/www/example.org/prod] /var/www/sdss.org/prod
# Source path:  : [/var/www/example.org/test] /var/www/sdss.org/test
# Deploy path:  : [/var/www/example.org/deploy] /var/www/sdss.org/deplooy
# Target database:  : [examplewp_prod ] sdsswp_dr15
# Source database:  : [examplewp_test] sdsswp_dr15_test
#
#
#
# Parameters:
#
# Target domain:  : www.sdss.org
# Source domain:  : test.sdss.org
# Target path:  : /var/www/sdss.org/prod
# Source path:  : /var/www/sdss.org/test
# Deploy path:  : /var/www/sdss.org/deplooy
# Target database:  : sdsswp_dr15
# Source database:  : sdsswp_dr15_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
#
#
# Parameters:
#
# Target domain:  : www.sdss.org
# Source domain:  : test.sdss.org
# Target path:  : /var/www/sdss.org/prod
# Source path:  : /var/www/sdss.org/test
# Deploy path:  : /var/www/sdss.org/deplooy
# Target database:  : sdsswp_dr15
# Source database:  : sdsswp_dr15_test
#
# Enter a new value or [enter] to keep existing value.
#
# Target domain:  : [www.sdss.org]
# Source domain:  : [test.sdss.org]
# Target path:  : [/var/www/sdss.org/prod]
# Source path:  : [/var/www/sdss.org/test]
# Deploy path:  : [/var/www/sdss.org/deplooy] /var/www/sdss.org/deploy
# Target database:  : [sdsswp_dr15]
# Source database:  : [sdsswp_dr15_test]
#
#
#
# Parameters:
#
# Target domain:  : www.sdss.org
# Source domain:  : test.sdss.org
# Target path:  : /var/www/sdss.org/prod
# Source path:  : /var/www/sdss.org/test
# Deploy path:  : /var/www/sdss.org/deploy
# Target database:  : sdsswp_dr15
# Source database:  : sdsswp_dr15_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
# W
# Enter parameters filename [defaults.yaml]sdss.yaml
#
# Parameters:
#
# Target domain:  : www.sdss.org
# Source domain:  : test.sdss.org
# Target path:  : /var/www/sdss.org/prod
# Source path:  : /var/www/sdss.org/test
# Deploy path:  : /var/www/sdss.org/deploy
# Target database:  : sdsswp_dr15
# Source database:  : sdsswp_dr15_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
#
#
# Parameters:
#
# Target domain:  : www.sdss.org
# Source domain:  : test.sdss.org
# Target path:  : /var/www/sdss.org/prod
# Source path:  : /var/www/sdss.org/test
# Deploy path:  : /var/www/sdss.org/deploy
# Target database:  : sdsswp_dr15
# Source database:  : sdsswp_dr15_test
#
# Enter a new value or [enter] to keep existing value.
#
# Target domain:  : [www.sdss.org] voyages.sdss.org
# Source domain:  : [test.sdss.org] test.voyages.sdss.org
# Target path:  : [/var/www/sdss.org/prod] /var/www/sdss.org/voyages
# Source path:  : [/var/www/sdss.org/test] /var/www/sdss.org/test.voyages
# Deploy path:  : [/var/www/sdss.org/deploy] deploy.voyages
# Target database:  : [sdsswp_dr15] voyageswp_prod
# Source database:  : [sdsswp_dr15_test] voyageswp_test
#
#
#
# Parameters:
#
# Target domain:  : voyages.sdss.org
# Source domain:  : test.voyages.sdss.org
# Target path:  : /var/www/sdss.org/voyages
# Source path:  : /var/www/sdss.org/test.voyages
# Deploy path:  : deploy.voyages
# Target database:  : voyageswp_prod
# Source database:  : voyageswp_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
# W
# Enter parameters filename [defaults.yaml]voyages
#
# Parameters:
#
# Target domain:  : voyages.sdss.org
# Source domain:  : test.voyages.sdss.org
# Target path:  : /var/www/sdss.org/voyages
# Source path:  : /var/www/sdss.org/test.voyages
# Deploy path:  : deploy.voyages
# Target database:  : voyageswp_prod
# Source database:  : voyageswp_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
#
#
# Parameters:
#
# Target domain:  : voyages.sdss.org
# Source domain:  : test.voyages.sdss.org
# Target path:  : /var/www/sdss.org/voyages
# Source path:  : /var/www/sdss.org/test.voyages
# Deploy path:  : deploy.voyages
# Target database:  : voyageswp_prod
# Source database:  : voyageswp_test
#
# Enter a new value or [enter] to keep existing value.
#
# Target domain:  : [voyages.sdss.org] www.sciserver.org
# Source domain:  : [test.voyages.sdss.org] test.sciserver.org
# Target path:  : [/var/www/sdss.org/voyages] /var/www/sciserver.org/prod
# Source path:  : [/var/www/sdss.org/test.voyages] /var/www/sciserver.org/test
# Deploy path:  : [deploy.voyages] /var/www/sciserver.org/deploy
# Target database:  : [voyageswp_prod] sciserverwp_prod
# Source database:  : [voyageswp_test] sciserverwp_test
#
#
#
# Parameters:
#
# Target domain:  : www.sciserver.org
# Source domain:  : test.sciserver.org
# Target path:  : /var/www/sciserver.org/prod
# Source path:  : /var/www/sciserver.org/test
# Deploy path:  : /var/www/sciserver.org/deploy
# Target database:  : sciserverwp_prod
# Source database:  : sciserverwp_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
# W
# Enter parameters filename [defaults.yaml]sciserver.yaml
#
# Parameters:
#
# Target domain:  : www.sciserver.org
# Source domain:  : test.sciserver.org
# Target path:  : /var/www/sciserver.org/prod
# Source path:  : /var/www/sciserver.org/test
# Deploy path:  : /var/www/sciserver.org/deploy
# Target database:  : sciserverwp_prod
# Source database:  : sciserverwp_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
# R
# Enter parameter filename [defaults.yaml]voyages
#
# Parameters:
#
# Target domain:  : voyages.sdss.org
# Source domain:  : test.voyages.sdss.org
# Target path:  : /var/www/sdss.org/voyages
# Source path:  : /var/www/sdss.org/test.voyages
# Deploy path:  : deploy.voyages
# Target database:  : voyageswp_prod
# Source database:  : voyageswp_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
#
#
# Parameters:
#
# Target domain:  : voyages.sdss.org
# Source domain:  : test.voyages.sdss.org
# Target path:  : /var/www/sdss.org/voyages
# Source path:  : /var/www/sdss.org/test.voyages
# Deploy path:  : deploy.voyages
# Target database:  : voyageswp_prod
# Source database:  : voyageswp_test
#
# Enter a new value or [enter] to keep existing value.
#
# Target domain:  : [voyages.sdss.org]
# Source domain:  : [test.voyages.sdss.org]
# Target path:  : [/var/www/sdss.org/voyages]
# Source path:  : [/var/www/sdss.org/test.voyages]
# Deploy path:  : [deploy.voyages] /var/www/sdss.org/deploy.voyages
# Target database:  : [voyageswp_prod]
# Source database:  : [voyageswp_test]
#
#
#
# Parameters:
#
# Target domain:  : voyages.sdss.org
# Source domain:  : test.voyages.sdss.org
# Target path:  : /var/www/sdss.org/voyages
# Source path:  : /var/www/sdss.org/test.voyages
# Deploy path:  : /var/www/sdss.org/deploy.voyages
# Target database:  : voyageswp_prod
# Source database:  : voyageswp_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
# W
# Enter parameters filename [defaults.yaml]voyages.yaml
#
# Parameters:
#
# Target domain:  : voyages.sdss.org
# Source domain:  : test.voyages.sdss.org
# Target path:  : /var/www/sdss.org/voyages
# Source path:  : /var/www/sdss.org/test.voyages
# Deploy path:  : /var/www/sdss.org/deploy.voyages
# Target database:  : voyageswp_prod
# Source database:  : voyageswp_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
#
#
# Parameters:
#
# Target domain:  : voyages.sdss.org
# Source domain:  : test.voyages.sdss.org
# Target path:  : /var/www/sdss.org/voyages
# Source path:  : /var/www/sdss.org/test.voyages
# Deploy path:  : /var/www/sdss.org/deploy.voyages
# Target database:  : voyageswp_prod
# Source database:  : voyageswp_test
#
# Enter a new value or [enter] to keep existing value.
#
# Target domain:  : [voyages.sdss.org] idies.jhu.edu
# Source domain:  : [test.voyages.sdss.org] test.idies.jhu.edu
# Target path:  : [/var/www/sdss.org/voyages] /var/www/idies.jhu.edu/prod
# Source path:  : [/var/www/sdss.org/test.voyages] /var/www/idies.jhu.edu/test
# Deploy path:  : [/var/www/sdss.org/deploy.voyages] /var/www/idies.jhu.edu/deploy
# Target database:  : [voyageswp_prod] idieswp_prod
# Source database:  : [voyageswp_test] idieswp_test
#
#
#
# Parameters:
#
# Target domain:  : idies.jhu.edu
# Source domain:  : test.idies.jhu.edu
# Target path:  : /var/www/idies.jhu.edu/prod
# Source path:  : /var/www/idies.jhu.edu/test
# Deploy path:  : /var/www/idies.jhu.edu/deploy
# Target database:  : idieswp_prod
# Source database:  : idieswp_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
# W
# Enter parameters filename [defaults.yaml]idies
#
# Parameters:
#
# Target domain:  : idies.jhu.edu
# Source domain:  : test.idies.jhu.edu
# Target path:  : /var/www/idies.jhu.edu/prod
# Source path:  : /var/www/idies.jhu.edu/test
# Deploy path:  : /var/www/idies.jhu.edu/deploy
# Target database:  : idieswp_prod
# Source database:  : idieswp_test
#
#
# R : [Read input parameters]
# X : E[X]it
# E : [E]dit input parameters
# W : [W]rite input parameters
# Choose an option: [E]
# X
